# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path = "testwall2.png"
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
# Apply Shi-Tomasi corner detection
corners = cv2.goodFeaturesToTrack(
    gray,
    maxCorners=4,         # Maximum number of corners to return
    qualityLevel=0.5,      # Minimum accepted quality of corners
    minDistance=10          # Minimum distance between corners
)
for i in range(len(corners)):
    x = int(corners[i][0][0])
    y = int(corners[i][0][1])
    cv2.circle(img, (x, y), 10, (0, 255, 0), -1)

plt.imshow(img, cmap='gray')

# %%
subsection = gray[200:300, 800:900];
corners = cv2.goodFeaturesToTrack(
    subsection,
    maxCorners=1,         # Maximum number of corners to return
    qualityLevel=0.5,      # Minimum accepted quality of corners
    minDistance=10          # Minimum distance between corners
)

for i in range(len(corners)):
    x = int(corners[i][0][0])
    y = int(corners[i][0][1])
    cv2.circle(subsection, (x, y), 10, (0, 255, 0), -1)

# %%
plt.imshow(subsection)

# %%
corners
# Out:
# array([[[856., 247.]],
#
#        [[830., 477.]],
#
#        [[351., 422.]],
#
#        [[377., 192.]]], dtype=float32)

# %%
for i in range(len(corners)):
    x = int(corners[i][0][0])
    y = int(corners[i][0][1])
    cv2.circle(img, (x, y), 10, (0, 255, 0), -1)

# %%
plt.imshow(img)

# %% [markdown]
# ## Chessboard Code

# %%
image_path = "chessboard.png"
img = cv2.imread(image_path)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
pattern_size = (20-1, 30-1)
ret, corners = cv2.findChessboardCorners(img, pattern_size)

# %%
if ret: # Corners exist
    cv2.drawChessboardCorners(img, pattern_size, corners, ret)

# %%
plt.imshow(img)

# %%
ret
# Out:
# False

# %%
corners
# Out:
# array([[[1258.0934  ,   66.55083 ]],
#
#        [[1258.032   ,  108.43159 ]],
#
#        [[1258.2051  ,  151.01985 ]],
#
#        ...,
#
#        [[  74.53384 ,  743.42554 ]],
#
#        [[  74.58842 ,  785.25507 ]],
#
#        [[  74.601074,  827.8237  ]]], dtype=float32)

# %% [markdown]
# ### In-Person

# %%
image_path = "corners1.jpg"
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
pattern_size = (8-1, 8-1)
ret, corners = cv2.findChessboardCorners(gray, pattern_size)

# Order of Corners: Starts from the top-right, goes down each column.
if ret: # Corners exist
    for i in range(len(corners)):
        # Top-Right corner is 0, 1, ps[0], ps[0]+1
        # Bottom-Left corner adds ps[0]
        # Last two elements add pattern_size[0] from first two.
        # if (i not in [0, 1, pattern_size[0], pattern_size[0]+1,
        #              pattern_size[0] - 1, pattern_size[0] - 2, 2*pattern_size[0] - 1, 2*pattern_size[0] - 2,
        #              len(corners)-1, len(corners) - 2, len(corners) - pattern_size[0], len(corners) - pattern_size[0] + 1,
        #              len(corners) - pattern_size[0] - 1,
        #              len(corners) - pattern_size[0] - 2,
        #              len(corners) - 2*pattern_size[0], 
        #               len(corners) - 2*pattern_size[0] + 1]):
        #     continue;
        x = int(corners[i][0][0])
        y = int(corners[i][0][1])
        cv2.circle(img, (x, y), 40, (0, 255, 0), -1)
        

plt.imshow(img)

# %%
x = []
y = []
for i in [0, 1, pattern_size[0], pattern_size[0]+1]:
    x.append(corners[i][0][0])
    y.append(corners[i][0][1])

print(x,y)
miny = int(min(y));
maxy = int(max(y));
minx = int(min(x));
maxx = int(max(x));

diffx = maxx - minx;
diffy = maxy - miny;

subsection = img[miny - 3*diffy//2 :maxy - 3*diffy//2, minx + 3*diffx//2: maxx+3*diffx//2];
plt.imshow(subsection)
# Out:
# [3400.5, 3393.054, 2977.8445, 2971.5] [2150.5, 2389.192, 2156.1892, 2394.5]

# %%
grays = cv2.cvtColor(subsection, cv2.COLOR_BGR2GRAY)
corners = cv2.goodFeaturesToTrack(
    grays,
    maxCorners=1,         # Maximum number of corners to return
    qualityLevel=0.5,      # Minimum accepted quality of corners
    minDistance=10          # Minimum distance between corners
)

# %%
corners
# Out:
# array([[[228., 118.]]], dtype=float32)

# %%
bestx = int(minx + 3*diffx//2 + corners[0][0][0])
besty = int(miny - 3*diffy//2 + corners[0][0][1])

# %%
cv2.circle(img, (bestx, besty), 40, (0, 255, 0), -1)
plt.imshow(img)

# %%
ys = [miny - 3*diffy//2, maxy - 3*diffy//2]
xs = [minx + 3*diffx//2, maxx + 3*diffx//2]
for x1 in xs:
    for y1 in ys:
        cv2.circle(img, (x1, y1), 40, (255, 255, 0), -1)

plt.imshow(img)

# %%
corners
#
# Vinecnt will ask for a demo of how the customers calculate the keystone correction parameters.
# He did mention that people project a chessboard with a white background.
# Goal: Try to make a rectangle of the same aspect ratio within the trapezoid.
# Aspect ratio depends on the output resolution of the projector.
# Default is 16:9, but we can read it from the projector if we have a connection to it.
# He will ask for the Bluetooth module for the projector.

# We need the homography matrix to map the corners of teh screen view (the projected output) to the internal image corners and how we will correct them.
# Vincent will ask how to fit the biggest rectangle into the distorted trapezoid.
# Out:
# array([[[3400.5    , 2150.5    ]],
#
#        [[3393.054  , 2389.192  ]],
#
#        [[3389.1794 , 2623.798  ]],
#
#        [[3384.0762 , 2858.4697 ]],
#
#        [[3380.     , 3093.     ]],
#
#        [[3375.     , 3325.     ]],
#
#        [[3372.5    , 3559.     ]],
#
#        [[2977.8445 , 2156.1892 ]],
#
#        [[2971.5    , 2394.5    ]],
#
#        [[2967.     , 2628.     ]],
#
#        [[2962.012  , 2861.6492 ]],
#
#        [[2960.4995 , 3092.3381 ]],
#
#        [[2955.     , 3327.     ]],
#
#        [[2952.5    , 3556.5    ]],
#
#        [[2558.5    , 2166.5    ]],
#
#        [[2554.5    , 2400.5    ]],
#
#        [[2551.5    , 2632.     ]],
#
#        [[2545.546  , 2864.7244 ]],
#
#        [[2543.2405 , 3092.718  ]],
#
#        [[2543.027  , 3323.043  ]],
#
#        [[2537.5    , 3555.5    ]],
#
#        [[2145.     , 2172.     ]],
#
#        [[2142.5    , 2405.5    ]],
#
#        [[2139.5    , 2637.5    ]],
#
#        [[2137.     , 2867.     ]],
#
#        [[2133.5    , 3095.5    ]],
#
#        [[2130.5    , 3325.     ]],
#
#        [[2126.1406 , 3554.377  ]],
#
#        [[1735.5    , 2178.5    ]],
#
#        [[1733.5    , 2411.     ]],
#
#        [[1731.5    , 2641.5    ]],
#
#        [[1729.     , 2870.5    ]],
#
#        [[1727.5    , 3099.5    ]],
#
#        [[1723.     , 3327.     ]],
#
#        [[1720.     , 3556.5    ]],
#
#        [[1328.5    , 2184.     ]],
#
#        [[1327.     , 2415.5    ]],
#
#        [[1325.     , 2644.5    ]],
#
#        [[1321.59   , 2873.8906 ]],
#
#        [[1321.     , 3102.5    ]],
#
#        [[1319.     , 3330.     ]],
#
#        [[1316.     , 3558.     ]],
#
#        [[ 921.     , 2185.     ]],
#
#        [[ 918.77997, 2417.9104 ]],
#
#        [[ 921.3227 , 2650.496  ]],
#
#        [[ 918.3927 , 2877.388  ]],
#
#        [[ 916.5    , 3106.     ]],
#
#        [[ 914.5    , 3333.     ]],
#
#        [[ 912.5328 , 3559.2483 ]]], dtype=float32)

# %%
len(corners)
# Out:
# 49

# %%
corners
# Out:
# array([[[3400.5    , 2150.5    ]],
#
#        [[3393.054  , 2389.192  ]],
#
#        [[3389.1794 , 2623.798  ]],
#
#        [[3384.0762 , 2858.4697 ]],
#
#        [[3380.     , 3093.     ]],
#
#        [[3375.     , 3325.     ]],
#
#        [[3372.5    , 3559.     ]],
#
#        [[2977.8445 , 2156.1892 ]],
#
#        [[2971.5    , 2394.5    ]],
#
#        [[2967.     , 2628.     ]],
#
#        [[2962.012  , 2861.6492 ]],
#
#        [[2960.4995 , 3092.3381 ]],
#
#        [[2955.     , 3327.     ]],
#
#        [[2952.5    , 3556.5    ]],
#
#        [[2558.5    , 2166.5    ]],
#
#        [[2554.5    , 2400.5    ]],
#
#        [[2551.5    , 2632.     ]],
#
#        [[2545.546  , 2864.7244 ]],
#
#        [[2543.2405 , 3092.718  ]],
#
#        [[2543.027  , 3323.043  ]],
#
#        [[2537.5    , 3555.5    ]],
#
#        [[2145.     , 2172.     ]],
#
#        [[2142.5    , 2405.5    ]],
#
#        [[2139.5    , 2637.5    ]],
#
#        [[2137.     , 2867.     ]],
#
#        [[2133.5    , 3095.5    ]],
#
#        [[2130.5    , 3325.     ]],
#
#        [[2126.1406 , 3554.377  ]],
#
#        [[1735.5    , 2178.5    ]],
#
#        [[1733.5    , 2411.     ]],
#
#        [[1731.5    , 2641.5    ]],
#
#        [[1729.     , 2870.5    ]],
#
#        [[1727.5    , 3099.5    ]],
#
#        [[1723.     , 3327.     ]],
#
#        [[1720.     , 3556.5    ]],
#
#        [[1328.5    , 2184.     ]],
#
#        [[1327.     , 2415.5    ]],
#
#        [[1325.     , 2644.5    ]],
#
#        [[1321.59   , 2873.8906 ]],
#
#        [[1321.     , 3102.5    ]],
#
#        [[1319.     , 3330.     ]],
#
#        [[1316.     , 3558.     ]],
#
#        [[ 921.     , 2185.     ]],
#
#        [[ 918.77997, 2417.9104 ]],
#
#        [[ 921.3227 , 2650.496  ]],
#
#        [[ 918.3927 , 2877.388  ]],
#
#        [[ 916.5    , 3106.     ]],
#
#        [[ 914.5    , 3333.     ]],
#
#        [[ 912.5328 , 3559.2483 ]]], dtype=float32)
